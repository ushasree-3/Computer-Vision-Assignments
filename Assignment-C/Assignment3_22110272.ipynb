# %% [markdown]
# This is submssion template for the assignment 3, Panaroma Stitching.
#
# Refer https://github.com/shash29-dev/ES666-Assignment3 to access the assignment.
#
# A `readme.md` file is provided in the repository with instructions.
#
# If you face any issues or have queries, try opening a issue on github itself. All queries will be addressed through github issues only.

# %%
# %cd /content
# !git clone https://github.com/ushasree-3/ES666-Assignment3.git  # Change with your Fork
# %cd ES666-Assignment3
# !python main.py

# Want to create backup in your drive?
# from google.colab import drive
# drive.mount('/content/drive')
# !cp /content/ES666-Assignment3 /content/drive/MyDrive/ES666_Assignment3  # This Path should Exist In your drive!
# Out:
# /content
# fatal: destination path 'ES666-Assignment3' already exists and is not an empty directory.
# /content/ES666-Assignment3
# ****************	Running Awesome Stitcher developed by: Ushasree  | 1 of 4	********************
# 		 Processing... Images/I1
# Identified 1756 valid matches between images.
# Calculated left homography for image 2.
# Identified 2251 valid matches between images.
# Calculated left homography for image 1.
# Identified 828 valid matches between images.
# Calculated left homography for image 0.
# Identified 2936 valid matches between images.
# Calculated right homography for image 4.
# Identified 1542 valid matches between images.
# Calculated right homography for image 5.
# Blended image 0 into the panorama.
# Blended image 1 into the panorama.
# Blended image 2 into the panorama.
# Blended image 3 into the panorama.
# Blended image 4 into the panorama.
# Blended image 5 into the panorama.
# [array([[ 9.75161119e-01, -9.69820902e-02, -4.89153226e+03],
# ...

# %%
import matplotlib.pyplot as plt
import glob
allims = glob.glob('/content/ES666-Assignment3/results/*/Ushasree*.png')
for im in allims:
  plt.figure()
  plt.axis('off')
  plt.imshow(plt.imread(im))

# %%
import matplotlib.pyplot as plt
import glob
allims = glob.glob('/content/ES666-Assignment3/results/*/JaneDoe*.png')  # replace JaneDoe by your folder name
for im in allims:
  plt.figure()
  plt.axis('off')
  plt.imshow(plt.imread(im))
